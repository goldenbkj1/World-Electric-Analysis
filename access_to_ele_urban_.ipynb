# %%
import json

# %%
with open('C:\\Users\\USER\\Downloads\\API_EG.ELC.ACCS.UR.ZS_DS2_en_csv_v2_4367536.json','r') as j:
    contents=json.loads(j.read())

# %%
type(contents)
# Out:
# list

# %%
import pandas as pd

# %%
df1=pd.DataFrame(contents)

# %%
df1.head()
# Out:
#                             0             1   \
# 0            Last Updated Date    2022-07-20
# 1                 Country Name  Country Code
# 2                        Aruba           ABW
# 3  Africa Eastern and Southern           AFE
# 4                  Afghanistan           AFG
#
#                                                   2                  3   \
# 0
# 1                                     Indicator Name     Indicator Code
# 2  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
# 3  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
# 4  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
#
#        4       5       6       7       8       9   ...                57  \
# 0     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 1  1960.0  1961.0  1962.0  1963.0  1964.0  1965.0  ...              2013
# 2     NaN     NaN     NaN     NaN     NaN     NaN  ...               100
# 3     NaN     NaN     NaN     NaN     NaN     NaN  ...  67.1122062807782
# 4     NaN     NaN     NaN     NaN     NaN     NaN  ...  92.2590484619141
#
#                  58                59                60                61  \
# 0
# 1              2014              2015              2016              2017
# 2               100               100               100               100
# 3  66.2834263727233  67.0802345160891  69.1322924194883  70.9285671571016
# 4  98.6999969482422              92.5              99.5              99.5
#
#                  62                63                64      65  66
# 0                                                           NaN
# 1              2018              2019              2020  2021.0
# 2               100               100               100     NaN
# 3  71.8661360685467  73.3328420364472  73.9429490467264     NaN
# 4  99.6260223388672              99.5              99.5     NaN
#
# [5 rows x 67 columns]

# %%
df1.drop(index=0,inplace=True)

# %%
df2=df1.rename(columns=df1.iloc[0])
df2.head()
# Out:
#                   Country Name  Country Code  \
# 1                 Country Name  Country Code
# 2                        Aruba           ABW
# 3  Africa Eastern and Southern           AFE
# 4                  Afghanistan           AFG
# 5   Africa Western and Central           AFW
#
#                                       Indicator Name     Indicator Code  \
# 1                                     Indicator Name     Indicator Code
# 2  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
# 3  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
# 4  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
# 5  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
#
#    1960.0  1961.0  1962.0  1963.0  1964.0  1965.0  ...              2013  \
# 1  1960.0  1961.0  1962.0  1963.0  1964.0  1965.0  ...              2013
# 2     NaN     NaN     NaN     NaN     NaN     NaN  ...               100
# 3     NaN     NaN     NaN     NaN     NaN     NaN  ...  67.1122062807782
# 4     NaN     NaN     NaN     NaN     NaN     NaN  ...  92.2590484619141
# 5     NaN     NaN     NaN     NaN     NaN     NaN  ...  78.8486136952441
#
#                2014              2015              2016              2017  \
# 1              2014              2015              2016              2017
# 2               100               100               100               100
# 3  66.2834263727233  67.0802345160891  69.1322924194883  70.9285671571016
# 4  98.6999969482422              92.5              99.5              99.5
# 5    79.52923504769  78.2478757011491  81.5715174202803
#
#                2018              2019              2020  2021.0
# 1              2018              2019              2020  2021.0
# 2               100               100               100     NaN
# 3  71.8661360685467  73.3328420364472  73.9429490467264     NaN
# 4  99.6260223388672              99.5              99.5     NaN
# 5                                       83.220064935553     NaN
#
# [5 rows x 67 columns]

# %%
df2.drop(index=1,inplace=True)

# %%
df2.head()
# Out:
#                   Country Name Country Code  \
# 2                        Aruba          ABW
# 3  Africa Eastern and Southern          AFE
# 4                  Afghanistan          AFG
# 5   Africa Western and Central          AFW
# 6                       Angola          AGO
#
#                                       Indicator Name     Indicator Code  \
# 2  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
# 3  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
# 4  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
# 5  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
# 6  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
#
#    1960.0  1961.0  1962.0  1963.0  1964.0  1965.0  ...              2013  \
# 2     NaN     NaN     NaN     NaN     NaN     NaN  ...               100
# 3     NaN     NaN     NaN     NaN     NaN     NaN  ...  67.1122062807782
# 4     NaN     NaN     NaN     NaN     NaN     NaN  ...  92.2590484619141
# 5     NaN     NaN     NaN     NaN     NaN     NaN  ...  78.8486136952441
# 6     NaN     NaN     NaN     NaN     NaN     NaN  ...   68.662223815918
#
#                2014              2015              2016              2017  \
# 2               100               100               100               100
# 3  66.2834263727233  67.0802345160891  69.1322924194883  70.9285671571016
# 4  98.6999969482422              92.5              99.5              99.5
# 5    79.52923504769  78.2478757011491  81.5715174202803
# 6                51                64  67.9733963012695  69.4111709594727
#
#                2018              2019              2020  2021.0
# 2               100               100               100     NaN
# 3  71.8661360685467  73.3328420364472  73.9429490467264     NaN
# 4  99.6260223388672              99.5              99.5     NaN
# 5                                       83.220064935553     NaN
# 6  65.2699966430664  72.2771835327148  73.7089157104492     NaN
#
# [5 rows x 67 columns]

# %% [markdown]
# # data cleaning

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 2 to 267
# Data columns (total 67 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960.0          0 non-null      float64
#  5   1961.0          0 non-null      float64
#  6   1962.0          0 non-null      float64
#  7   1963.0          0 non-null      float64
#  8   1964.0          0 non-null      float64
#  9   1965.0          0 non-null      float64
#  10  1966.0          0 non-null      float64
#  11  1967.0          0 non-null      float64
#  12  1968.0          0 non-null      float64
#  13  1969.0          0 non-null      float64
#  14  1970.0          0 non-null      float64
#  15  1971.0          0 non-null      float64
#  16  1972.0          0 non-null      float64
#  17  1973.0          0 non-null      float64
#  18  1974.0          0 non-null      float64
#  19  1975.0          0 non-null      float64
#  20  1976.0          0 non-null      float64
#  21  1977.0          0 non-null      float64
#  22  1978.0          0 non-null      float64
#  23  1979.0          0 non-null      float64
#  24  1980.0          0 non-null      float64
#  25  1981.0          0 non-null      float64
#  26  1982.0          0 non-null      float64
#  27  1983.0          0 non-null      float64
#  28  1984.0          0 non-null      float64
#  29  1985.0          0 non-null      float64
#  30  1986.0          0 non-null      float64
#  31  1987.0          0 non-null      float64
#  32  1988.0          0 non-null      float64
#  33  1989.0          0 non-null      float64
#  34  1990            266 non-null    object
#  35  1991            266 non-null    object
#  36  1992            266 non-null    object
#  37  1993            266 non-null    object
#  38  1994            266 non-null    object
#  39  1995            266 non-null    object
#  40  1996            266 non-null    object
#  41  1997            266 non-null    object
#  42  1998            266 non-null    object
#  43  1999            266 non-null    object
#  44  2000            266 non-null    object
#  45  2001            266 non-null    object
#  46  2002            266 non-null    object
#  47  2003            266 non-null    object
#  48  2004            266 non-null    object
#  49  2005            266 non-null    object
#  50  2006            266 non-null    object
#  51  2007            266 non-null    object
#  52  2008            266 non-null    object
#  53  2009            266 non-null    object
#  54  2010            266 non-null    object
#  55  2011            266 non-null    object
#  56  2012            266 non-null    object
#  57  2013            266 non-null    object
#  58  2014            266 non-null    object
#  59  2015            266 non-null    object
#  60  2016            266 non-null    object
#  61  2017            266 non-null    object
#  62  2018            266 non-null    object
#  63  2019            266 non-null    object
#  64  2020            266 non-null    object
#  65  2021.0          0 non-null      float64
#  66                  266 non-null    object
# dtypes: float64(31), object(36)
# memory usage: 139.4+ KB

# %%
df2.shape
# Out:
# (266, 67)

# %%
df2.columns
# Out:
# Index([  'Country Name',   'Country Code', 'Indicator Name', 'Indicator Code',
#                  1960.0,           1961.0,           1962.0,           1963.0,
#                  1964.0,           1965.0,           1966.0,           1967.0,
#                  1968.0,           1969.0,           1970.0,           1971.0,
#                  1972.0,           1973.0,           1974.0,           1975.0,
#                  1976.0,           1977.0,           1978.0,           1979.0,
#                  1980.0,           1981.0,           1982.0,           1983.0,
#                  1984.0,           1985.0,           1986.0,           1987.0,
#                  1988.0,           1989.0,           '1990',           '1991',
#                  '1992',           '1993',           '1994',           '1995',
#                  '1996',           '1997',           '1998',           '1999',
#                  '2000',           '2001',           '2002',           '2003',
#                  '2004',           '2005',           '2006',           '2007',
#                  '2008',           '2009',           '2010',           '2011',
#                  '2012',           '2013',           '2014',           '2015',
#                  '2016',           '2017',           '2018',           '2019',
#                  '2020',           2021.0,               ''],
#       dtype='object')

# %%
df3=df2.drop(columns=[ 1960.0,           1961.0,           1962.0,           1963.0,
                 1964.0,           1965.0,           1966.0,           1967.0,
                 1968.0,           1969.0,           1970.0,           1971.0,
                 1972.0,           1973.0,           1974.0,           1975.0,
                 1976.0,           1977.0,           1978.0,           1979.0,
                 1980.0,           1981.0,           1982.0,           1983.0,
                 1984.0,           1985.0,           1986.0,           1987.0,
                 1988.0,           1989.0,           2021.0])

# %%
df3.head()
# Out:
#                   Country Name Country Code  \
# 2                        Aruba          ABW
# 3  Africa Eastern and Southern          AFE
# 4                  Afghanistan          AFG
# 5   Africa Western and Central          AFW
# 6                       Angola          AGO
#
#                                       Indicator Name     Indicator Code 1990  \
# 2  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS  100
# 3  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
# 4  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
# 5  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
# 6  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
#
#                1991             1992              1993              1994  \
# 2  99.9241333007813  99.966064453125  99.9903564453125               100
# 3
# 4
# 5                                     76.3798903017662  76.4140186640721
# 6
#
#                1995  ...              2012              2013  \
# 2               100  ...               100               100
# 3                    ...  66.9452771502516  67.1122062807782
# 4                    ...                95  92.2590484619141
# 5  76.2217529588441  ...  78.6990973259095  78.8486136952441
# 6                    ...  70.4634704589844   68.662223815918
#
#                2014              2015              2016              2017  \
# 2               100               100               100               100
# 3  66.2834263727233  67.0802345160891  69.1322924194883  70.9285671571016
# 4  98.6999969482422              92.5              99.5              99.5
# 5    79.52923504769  78.2478757011491  81.5715174202803
# 6                51                64  67.9733963012695  69.4111709594727
#
#                2018              2019              2020
# 2               100               100               100
# 3  71.8661360685467  73.3328420364472  73.9429490467264
# 4  99.6260223388672              99.5              99.5
# 5                                       83.220064935553
# 6  65.2699966430664  72.2771835327148  73.7089157104492
#
# [5 rows x 36 columns]

# %%
df3.isna().sum()
# Out:
# Country Name      0
# Country Code      0
# Indicator Name    0
# Indicator Code    0
# 1990              0
# 1991              0
# 1992              0
# 1993              0
# 1994              0
# 1995              0
# 1996              0
# 1997              0
# 1998              0
# 1999              0
# 2000              0
# 2001              0
# 2002              0
# 2003              0
# 2004              0
# 2005              0
# 2006              0
# 2007              0
# 2008              0
# 2009              0
# 2010              0
# 2011              0
# 2012              0
# 2013              0
# 2014              0
# 2015              0
# 2016              0
# 2017              0
# 2018              0
# 2019              0
# 2020              0
#                   0
# dtype: int64

# %%
df4=pd.read_csv('C:\\Users\\USER\\Downloads\\Metadata_Country_API_EG.ELC.ACCS.UR.ZS_DS2_en_csv_v2_4367536.csv')

# %%
df4
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFE                         NaN                  NaN
# 2            AFG                  South Asia           Low income
# 3            AFW                         NaN                  NaN
# 4            AGO          Sub-Saharan Africa  Lower middle income
# ..           ...                         ...                  ...
# 260          XKX       Europe & Central Asia  Upper middle income
# 261          YEM  Middle East & North Africa           Low income
# 262          ZAF          Sub-Saharan Africa  Upper middle income
# 263          ZMB          Sub-Saharan Africa           Low income
# 264          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes  \
# 0                                                  NaN
# 1    26 countries, stretching from the Red Sea in t...
# 2    The reporting period for national accounts dat...
# 3    22 countries, stretching from the westernmost ...
# 4    The World Bank systematically assesses the app...
# ..                                                 ...
# 260                                                NaN
# 261  The World Bank systematically assesses the app...
# 262  Fiscal year end: March 31; reporting period fo...
# 263  National accounts data were rebased to reflect...
# 264  National Accounts data are reported in Zimbabw...
#
#                        TableName  Unnamed: 5
# 0                          Aruba         NaN
# 1    Africa Eastern and Southern         NaN
# 2                    Afghanistan         NaN
# 3     Africa Western and Central         NaN
# 4                         Angola         NaN
# ..                           ...         ...
# 260                       Kosovo         NaN
# 261                  Yemen, Rep.         NaN
# 262                 South Africa         NaN
# 263                       Zambia         NaN
# 264                     Zimbabwe         NaN
#
# [265 rows x 6 columns]

# %%
df4.isna().sum()
# Out:
# Country Code      0
# Region           48
# IncomeGroup      49
# SpecialNotes    139
# TableName         0
# Unnamed: 5      265
# dtype: int64

# %%
df4.drop(columns='Unnamed: 5',inplace=True)

# %%
df4['SpecialNotes'].fillna(df4['SpecialNotes'].mode()[0],inplace=True)

# %%
df4['IncomeGroup'].fillna(df4['IncomeGroup'].mode()[0],inplace=True)

# %%
df4['Region'].fillna(df4['Region'].mode()[0],inplace=True)

# %%
for i in df4.columns:
    print(df4[i].value_counts())
    print('....................')
# Out:
# ABW    1
# OSS    1
# MYS    1
# NAC    1
# NAM    1
#       ..
# GUY    1
# HIC    1
# HKG    1
# HND    1
# ZWE    1
# Name: Country Code, Length: 265, dtype: int64
# ....................
# Europe & Central Asia         106
# Sub-Saharan Africa             48
# Latin America & Caribbean      42
# East Asia & Pacific            37
# Middle East & North Africa     21
# South Asia                      8
# North America                   3
# Name: Region, dtype: int64
# ....................
# High income            129
# Lower middle income     54
# Upper middle income     54
# Low income              28
# Name: IncomeGroup, dtype: int64
# ....................
# Fiscal year end: March 31; reporting period for national accounts data: CY.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            146
# The reporting period for national accounts data is designated as either calendar year basis (CY) or fiscal year basis (FY). For this country, it is fiscal year-based (fiscal year-end: June 30). Also, an estimate (PA.NUS.ATLS) of the exchange rate covers the same period and thus differs from the official exchange rate (CY).                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     7
# Fiscal year end: June 30; reporting period for national accounts data: CY.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               2
# Fiscal year ends on September 30; reporting period for national accounts data: FY.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       2
# National accounts data are provided in the US dollar.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    2
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# The DEC conversion is not reported when national accounts data are unavailable.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          1
# The World Bank systematically assesses the appropriateness of official exchange rates as conversion factors. In this country, multiple or dual exchange rate activity exists and must be accounted for appropriately in underlying statistics. An alternative estimate (“alternative conversion factor” - PA.NUS.ATLS) is thus calculated as a weighted average of the different exchange rates in use in the country. Doing so better reflects economic reality and leads to more accurate cross-country comparisons and country classifications by income level. For this country, this applies to the period 1974-1987. Alternative conversion factors are used in the Atlas methodology and elsewhere in World Development Indicators as single-year conversion factors.                                                                                                                             1
# Includes self-governed areas only, which mostly exclude Abkhazia and South Ossetia, but small areas in Abkhazia and South Ossetia are included before 2008 or 2009 because of the changes in self-governed areas.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        1
# Fiscal year ends on September 30; reporting period for national accounts data: FY. The source for national accounts data is the Pacific and Virgin Islands Training Initiative.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          1
# National Accounts data are reported in Zimbabwean Dollar (ZWL). Before 2017, one ZWL is set to be equal to one USD.\n\nThe World Bank systematically assesses the appropriateness of official exchange rates as conversion factors. In this country, multiple or dual exchange rate activity exists and must be accounted for appropriately in underlying statistics. An alternative estimate (“alternative conversion factor” - PA.NUS.ATLS) is thus calculated as a weighted average of the different exchange rates in use in the country. Doing so better reflects economic reality and leads to more accurate cross-country comparisons and country classifications by income level. For this country, this applies to the period 2017-2020. Alternative conversion factors are used in the Atlas methodology and elsewhere in World Development Indicators as single-year conversion factors.      1
# Name: SpecialNotes, Length: 111, dtype: int64
# ....................
# Aruba                   1
# Other small states      1
# Malaysia                1
# North America           1
# Namibia                 1
#                        ..
# Guyana                  1
# High income             1
# Hong Kong SAR, China    1
# Honduras                1
# Zimbabwe                1
# Name: TableName, Length: 265, dtype: int64
# ....................

# %%
df4.isna().sum()
# Out:
# Country Code    0
# Region          0
# IncomeGroup     0
# SpecialNotes    0
# TableName       0
# dtype: int64

# %%
df4
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFE       Europe & Central Asia          High income
# 2            AFG                  South Asia           Low income
# 3            AFW       Europe & Central Asia          High income
# 4            AGO          Sub-Saharan Africa  Lower middle income
# ..           ...                         ...                  ...
# 260          XKX       Europe & Central Asia  Upper middle income
# 261          YEM  Middle East & North Africa           Low income
# 262          ZAF          Sub-Saharan Africa  Upper middle income
# 263          ZMB          Sub-Saharan Africa           Low income
# 264          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes  \
# 0    Fiscal year end: March 31; reporting period fo...
# 1    26 countries, stretching from the Red Sea in t...
# 2    The reporting period for national accounts dat...
# 3    22 countries, stretching from the westernmost ...
# 4    The World Bank systematically assesses the app...
# ..                                                 ...
# 260  Fiscal year end: March 31; reporting period fo...
# 261  The World Bank systematically assesses the app...
# 262  Fiscal year end: March 31; reporting period fo...
# 263  National accounts data were rebased to reflect...
# 264  National Accounts data are reported in Zimbabw...
#
#                        TableName
# 0                          Aruba
# 1    Africa Eastern and Southern
# 2                    Afghanistan
# 3     Africa Western and Central
# 4                         Angola
# ..                           ...
# 260                       Kosovo
# 261                  Yemen, Rep.
# 262                 South Africa
# 263                       Zambia
# 264                     Zimbabwe
#
# [265 rows x 5 columns]

# %%
df5=pd.read_csv('C:\\Users\\USER\\Downloads\\Metadata_Indicator_API_EG.ELC.ACCS.UR.ZS_DS2_en_csv_v2_4367536.csv')

# %%
df5
# Out:
#       INDICATOR_CODE                                     INDICATOR_NAME  \
# 0  EG.ELC.ACCS.UR.ZS  Access to electricity, urban (% of urban popul...
#
#                                          SOURCE_NOTE  \
# 0  Access to electricity, urban is the percentage...
#
#                                  SOURCE_ORGANIZATION  Unnamed: 4
# 0  World Bank Global Electrification Database fro...         NaN

# %%
df5.drop(columns='Unnamed: 4',inplace=True)

# %%
df5.isna().sum()
# Out:
# INDICATOR_CODE         0
# INDICATOR_NAME         0
# SOURCE_NOTE            0
# SOURCE_ORGANIZATION    0
# dtype: int64

# %%
df3.head(1)
# Out:
#   Country Name Country Code  \
# 2        Aruba          ABW
#
#                                       Indicator Name     Indicator Code 1990  \
# 2  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS  100
#
#                1991             1992              1993 1994 1995  ... 2012  \
# 2  99.9241333007813  99.966064453125  99.9903564453125  100  100  ...  100
#
#   2013 2014 2015 2016 2017 2018 2019 2020
# 2  100  100  100  100  100  100  100  100
#
# [1 rows x 36 columns]

# %%
df4.head(1)
# Out:
#   Country Code                     Region  IncomeGroup  \
# 0          ABW  Latin America & Caribbean  High income
#
#                                         SpecialNotes TableName
# 0  Fiscal year end: March 31; reporting period fo...     Aruba

# %%
df6=df3.merge(df5,left_on='Indicator Code',right_on='INDICATOR_CODE')

# %%
df6.head(1)
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
#
#                                       Indicator Name     Indicator Code 1990  \
# 0  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS  100
#
#                1991             1992              1993 1994 1995  ... 2016  \
# 0  99.9241333007813  99.966064453125  99.9903564453125  100  100  ...  100
#
#   2017 2018 2019 2020       INDICATOR_CODE  \
# 0  100  100  100  100    EG.ELC.ACCS.UR.ZS
#
#                                       INDICATOR_NAME  \
# 0  Access to electricity, urban (% of urban popul...
#
#                                          SOURCE_NOTE  \
# 0  Access to electricity, urban is the percentage...
#
#                                  SOURCE_ORGANIZATION
# 0  World Bank Global Electrification Database fro...
#
# [1 rows x 40 columns]

# %%
df=df6.merge(df4,left_on='Country Code',right_on='Country Code')

# %%
df
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 260                       Kosovo          XKX
# 261                  Yemen, Rep.          YEM
# 262                 South Africa          ZAF
# 263                       Zambia          ZMB
# 264                     Zimbabwe          ZWE
#
#                                         Indicator Name     Indicator Code  \
# 0    Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
# 1    Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
# 2    Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
# 3    Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
# 4    Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
# ..                                                 ...                ...
# 260  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
# 261  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
# 262  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
# 263  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
# 264  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
#
#      1990              1991              1992              1993  \
# 0     100  99.9241333007813   99.966064453125  99.9903564453125
# 1
# 2
# 3                                              76.3798903017662
# 4
# ..    ...               ...               ...               ...
# 260   100               100               100               100
# 261                                      91.2  91.6290969848633
# 262
# 263  34.7  35.1093902587891              39.2  37.5866508483887
# 264                          85.4796600341797  85.5194854736328
#
#                  1994              1995  ...              2020     \
# 0                 100               100  ...               100
# 1                                        ...  73.9429490467264
# 2                                        ...              99.5
# 3    76.4140186640721  76.2217529588441  ...   83.220064935553
# 4                                        ...  73.7089157104492
# ..                ...               ...  ...               ... ..
# 260               100               100  ...
# 261  91.7269134521484  91.8152618408203  ...  93.1134567260742
# 262                                      ...   88.806266784668
# 263     38.8173828125  40.0386352539063  ...  82.3826217651367
# 264              80.4   85.577018737793  ...  85.7154769897461
#
#         INDICATOR_CODE                                     INDICATOR_NAME  \
# 0    EG.ELC.ACCS.UR.ZS  Access to electricity, urban (% of urban popul...
# 1    EG.ELC.ACCS.UR.ZS  Access to electricity, urban (% of urban popul...
# 2    EG.ELC.ACCS.UR.ZS  Access to electricity, urban (% of urban popul...
# 3    EG.ELC.ACCS.UR.ZS  Access to electricity, urban (% of urban popul...
# 4    EG.ELC.ACCS.UR.ZS  Access to electricity, urban (% of urban popul...
# ..                 ...                                                ...
# 260  EG.ELC.ACCS.UR.ZS  Access to electricity, urban (% of urban popul...
# 261  EG.ELC.ACCS.UR.ZS  Access to electricity, urban (% of urban popul...
# 262  EG.ELC.ACCS.UR.ZS  Access to electricity, urban (% of urban popul...
# 263  EG.ELC.ACCS.UR.ZS  Access to electricity, urban (% of urban popul...
# 264  EG.ELC.ACCS.UR.ZS  Access to electricity, urban (% of urban popul...
#
#                                            SOURCE_NOTE  \
# 0    Access to electricity, urban is the percentage...
# 1    Access to electricity, urban is the percentage...
# 2    Access to electricity, urban is the percentage...
# 3    Access to electricity, urban is the percentage...
# 4    Access to electricity, urban is the percentage...
# ..                                                 ...
# 260  Access to electricity, urban is the percentage...
# 261  Access to electricity, urban is the percentage...
# 262  Access to electricity, urban is the percentage...
# 263  Access to electricity, urban is the percentage...
# 264  Access to electricity, urban is the percentage...
#
#                                    SOURCE_ORGANIZATION  \
# 0    World Bank Global Electrification Database fro...
# 1    World Bank Global Electrification Database fro...
# 2    World Bank Global Electrification Database fro...
# 3    World Bank Global Electrification Database fro...
# 4    World Bank Global Electrification Database fro...
# ..                                                 ...
# 260  World Bank Global Electrification Database fro...
# 261  World Bank Global Electrification Database fro...
# 262  World Bank Global Electrification Database fro...
# 263  World Bank Global Electrification Database fro...
# 264  World Bank Global Electrification Database fro...
#
#                          Region          IncomeGroup  \
# 0     Latin America & Caribbean          High income
# 1         Europe & Central Asia          High income
# 2                    South Asia           Low income
# 3         Europe & Central Asia          High income
# 4            Sub-Saharan Africa  Lower middle income
# ..                          ...                  ...
# 260       Europe & Central Asia  Upper middle income
# 261  Middle East & North Africa           Low income
# 262          Sub-Saharan Africa  Upper middle income
# 263          Sub-Saharan Africa           Low income
# 264          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes  \
# 0    Fiscal year end: March 31; reporting period fo...
# 1    26 countries, stretching from the Red Sea in t...
# 2    The reporting period for national accounts dat...
# 3    22 countries, stretching from the westernmost ...
# 4    The World Bank systematically assesses the app...
# ..                                                 ...
# 260  Fiscal year end: March 31; reporting period fo...
# 261  The World Bank systematically assesses the app...
# 262  Fiscal year end: March 31; reporting period fo...
# 263  National accounts data were rebased to reflect...
# 264  National Accounts data are reported in Zimbabw...
#
#                        TableName
# 0                          Aruba
# 1    Africa Eastern and Southern
# 2                    Afghanistan
# 3     Africa Western and Central
# 4                         Angola
# ..                           ...
# 260                       Kosovo
# 261                  Yemen, Rep.
# 262                 South Africa
# 263                       Zambia
# 264                     Zimbabwe
#
# [265 rows x 44 columns]

# %%
df.to_csv('C:\\Users\\USER\\Desktop\\World_Electric_analysis\\access_to_ele_urban%.csv')
